# %%
import pandas as pd

df_sales = pd.read_csv("cleaned_games.csv")
df_customer = pd.read_csv("sorted.csv")
df_sales.rename(columns={'title': 'name'}, inplace=True)
display(df_customer.columns)

display(df_sales.columns)

df_merged = pd.merge(df_customer, df_sales, on='name', how='inner')
display(df_merged.columns)

df_merged.to_csv('merged_data.csv', index=False)
# Out:
# Index(['name', 'platform', 'year', 'decade', 'genre', 'publisher', 'na_sales',
#        'eu_sales', 'jp_sales', 'other_sales', 'global_sales', 'na_share',
#        'eu_share', 'jp_share', 'other_share', 'rank', 'platform_group'],
#       dtype='object')
# Index(['name', 'team', 'sub_team', 'summary', 'sub_genres', 'rating',
#        'times_listed', 'number_of_reviews', 'plays', 'playing', 'backlogs',
#        'wishlist', 'time_since_release', 'reviews', 'genre'],
#       dtype='object')
# Index(['name', 'platform', 'year', 'decade', 'genre_x', 'publisher',
#        'na_sales', 'eu_sales', 'jp_sales', 'other_sales', 'global_sales',
#        'na_share', 'eu_share', 'jp_share', 'other_share', 'rank',
#        'platform_group', 'team', 'sub_team', 'summary', 'sub_genres', 'rating',
#        'times_listed', 'number_of_reviews', 'plays', 'playing', 'backlogs',
#        'wishlist', 'time_since_release', 'reviews', 'genre_y'],
#       dtype='object')

# %%
# Out:
#                 name platform    year  decade   genre_x publisher  na_sales  \
# 0         Wii Sports      WII  2006.0  2000.0    Sports  Nintendo     41.49
# 1  Super Mario Bros.      NES  1985.0  1980.0  Platform  Nintendo     29.08
# 2     Mario Kart Wii      WII  2008.0  2000.0    Racing  Nintendo     15.85
# 3             Tetris       GB  1989.0  1980.0    Puzzle  Nintendo     23.20
# 4             Tetris       GB  1989.0  1980.0    Puzzle  Nintendo     23.20
#
#    eu_sales  jp_sales  other_sales  ...  rating  times_listed  \
# 0     29.02      3.77         8.46  ...     3.7         775.0
# 1      3.58      6.81         0.77  ...     3.5        1500.0
# 2     12.88      3.79         3.31  ...     3.9        1000.0
# 3      2.26      4.22         0.58  ...     4.1         688.0
# 4      2.26      4.22         0.58  ...     4.0         197.0
#
#    number_of_reviews    plays  playing  backlogs wishlist time_since_release  \
# 0              775.0  18000.0     39.0     320.0     93.0             9677.0
# 1             1500.0  18000.0     59.0     733.0    237.0             1940.0
# 2             1000.0  19000.0     88.0     461.0    168.0            10185.0
# 3              688.0   9600.0     54.0     175.0     66.0             3450.0
# 4              197.0   2500.0     18.0      76.0     21.0             3279.0
#
#                                              reviews    genre_y
# 0  ["The perfect arcade game. Another type of gam...  Simulator
# 1  ["I actually had no idea this game was so long...  Adventure
# 2  ["Completed to fulfill a childhood dream and i...     Racing
# 3  ['Fucking love Tetris. Timeless game.', 'A gre...     Arcade
# 4  ['Bundling this gem with the OG Game Boy was t...     Puzzle
#
# [5 rows x 31 columns]

# %% [markdown]
# ## Save merged data
#
# ### Subtask:
# Save the merged DataFrame to a new CSV file.

# %% [markdown]
# **Reasoning**:
# Save the merged DataFrame to a new CSV file without the index.
